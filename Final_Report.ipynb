# %% [markdown]
# # Final Report

# %% [markdown]
# ## Zillow: What is driving the errors in the Zestimates®?

# %% [markdown]
# ### Goals
# - To improve our original estimate of the log error by using clustering methodologies.
# - To find the key drivers of error in the Zestimate® figures.

# %% [markdown]
# ## 1. Acquire

# %% [markdown]
# ### Imports

# %%
# Set up the notebook imports
# Import Modules
import acquire
import prepare

# Basic Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Modeling Imports
from sklearn.cluster import KMeans, dbscan
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, LassoLars
from sklearn.preprocessing import PolynomialFeatures

# Modeling Metrics
from sklearn.metrics import mean_squared_error, explained_variance_score
from scipy import stats

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print('Imports Completed.')
# Out:
# Imports Completed.

# %%
# 260: residential general
# 261: single family residential
# 263: mobile home
# 264: townhouse
# 266: condominium 
# 279: inferred single family residential

# %%
df = acquire.zillow_data()
df.head()
# Out:
#    id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0   1  10759547                    NaN                       NaN
# 1   6  10933547                    NaN                       NaN
# 2  14  11142747                    NaN                       NaN
# 3  15  11193347                    NaN                       NaN
# 4  16  11215747                    NaN                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt buildingclasstypeid  \
# 0           NaN          0.0         0.0                None
# 1           NaN          0.0         0.0                None
# 2           NaN          0.0         0.0                None
# 3           NaN          0.0         0.0                None
# 4           NaN          0.0         0.0                None
#
#    buildingqualitytypeid  calculatedbathnbr  ...  assessmentyear  \
# 0                    NaN                NaN  ...          2015.0
# 1                    NaN                NaN  ...          2016.0
# 2                    NaN                NaN  ...          2015.0
# 3                    NaN                NaN  ...          2016.0
# 4                    NaN                NaN  ...          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                27516.0        NaN                None                 NaN
# 1               159016.0    6773.34                None                 NaN
# 2                 4265.0        NaN                None                 NaN
# 3                   10.0        NaN                None                 NaN
# 4                   10.0        NaN                None                 NaN
#
#    censustractandblock  id  parcelid  logerror  transactiondate
# 0                  NaN   1  17052889  0.055619       2017-01-01
# 1                  NaN   6  12095076 -0.001011       2017-01-01
# 2                  NaN  14  14731691 -0.008935       2017-01-02
# 3                  NaN  15  17110996  0.008669       2017-01-02
# 4                  NaN  16  14375300 -0.021896       2017-01-02
#
# [5 rows x 63 columns]

# %%
df.shape
# Out:
# (70364, 63)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70364 entries, 0 to 70363
# Data columns (total 63 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            70364 non-null  int64
#  1   parcelid                      70364 non-null  int64
#  2   airconditioningtypeid         19706 non-null  float64
#  3   architecturalstyletypeid      151 non-null    float64
#  4   basementsqft                  44 non-null     float64
#  5   bathroomcnt                   70364 non-null  float64
#  6   bedroomcnt                    70364 non-null  float64
#  7   buildingclasstypeid           0 non-null      object
#  8   buildingqualitytypeid         44451 non-null  float64
#  9   calculatedbathnbr             68177 non-null  float64
#  10  decktypeid                    487 non-null    float64
#  11  finishedfloor1squarefeet      5669 non-null   float64
#  12  calculatedfinishedsquarefeet  69345 non-null  float64
#  13  finishedsquarefeet12          68936 non-null  float64
#  14  finishedsquarefeet13          210 non-null    float64
#  15  finishedsquarefeet15          7 non-null      float64
#  16  finishedsquarefeet50          5669 non-null   float64
#  17  finishedsquarefeet6           192 non-null    float64
#  18  fips                          70364 non-null  float64
#  19  fireplacecnt                  8206 non-null   float64
#  20  fullbathcnt                   68177 non-null  float64
#  21  garagecarcnt                  22688 non-null  float64
#  22  garagetotalsqft               22688 non-null  float64
#  23  hashottuborspa                1256 non-null   float64
#  24  heatingorsystemtypeid         45349 non-null  float64
#  25  latitude                      70364 non-null  float64
#  26  longitude                     70364 non-null  float64
#  27  lotsizesquarefeet             63404 non-null  float64
#  28  poolcnt                       13890 non-null  float64
#  29  poolsizesum                   776 non-null    float64
#  30  pooltypeid10                  423 non-null    float64
#  31  pooltypeid2                   833 non-null    float64
#  32  pooltypeid7                   13041 non-null  float64
#  33  propertycountylandusecode     70364 non-null  object
#  34  propertylandusetypeid         70364 non-null  float64
#  35  propertyzoningdesc            44986 non-null  object
#  36  rawcensustractandblock        70364 non-null  float64
#  37  regionidcity                  68962 non-null  float64
#  38  regionidcounty                70364 non-null  float64
#  39  regionidneighborhood          27109 non-null  float64
#  40  regionidzip                   70105 non-null  float64
#  41  roomcnt                       70364 non-null  float64
#  42  storytypeid                   44 non-null     float64
#  43  threequarterbathnbr           8115 non-null   float64
#  44  typeconstructiontypeid        166 non-null    float64
#  45  unitcnt                       44712 non-null  float64
#  46  yardbuildingsqft17            2300 non-null   float64
#  47  yardbuildingsqft26            65 non-null     float64
#  48  yearbuilt                     69356 non-null  float64
#  49  numberofstories               17115 non-null  float64
#  50  fireplaceflag                 125 non-null    float64
#  51  structuretaxvaluedollarcnt    69216 non-null  float64
#  52  taxvaluedollarcnt             69443 non-null  float64
#  53  assessmentyear                70364 non-null  float64
#  54  landtaxvaluedollarcnt         68757 non-null  float64
#  55  taxamount                     69925 non-null  float64
#  56  taxdelinquencyflag            1321 non-null   object
#  57  taxdelinquencyyear            1321 non-null   float64
#  58  censustractandblock           68774 non-null  float64
#  59  id                            70364 non-null  int64
#  60  parcelid                      70364 non-null  int64
#  61  logerror                      70364 non-null  float64
#  62  transactiondate               70364 non-null  object
# dtypes: float64(54), int64(4), object(5)
# memory usage: 33.8+ MB

# %%
df.describe()
# Out:
#                  id      parcelid  airconditioningtypeid  \
# count  70364.000000  7.036400e+04           19706.000000
# mean   38948.813740  1.345496e+07               1.958033
# std    22408.699531  8.563498e+06               3.189763
# min        1.000000  1.071174e+07               1.000000
# 25%    19396.750000  1.157973e+07               1.000000
# 50%    39117.500000  1.261348e+07               1.000000
# 75%    58238.250000  1.416926e+07               1.000000
# max    77613.000000  1.696019e+08              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                151.000000     44.000000  70364.000000  70364.000000
# mean                   7.430464    591.818182      2.176887      3.025041
# std                    2.629347    466.160182      1.015034      1.110356
# min                    2.000000     63.000000      0.000000      0.000000
# 25%                    7.000000    219.000000      2.000000      2.000000
# 50%                    7.000000    528.000000      2.000000      3.000000
# 75%                    7.000000    744.500000      3.000000      4.000000
# max                   21.000000   2443.000000     20.000000     25.000000
#
#        buildingqualitytypeid  calculatedbathnbr  decktypeid  ...  \
# count           44451.000000       68177.000000       487.0  ...
# mean                6.395177           2.245882        66.0  ...
# std                 1.700978           0.952441         0.0  ...
# min                 1.000000           1.000000        66.0  ...
# 25%                 5.000000           2.000000        66.0  ...
# 50%                 6.000000           2.000000        66.0  ...
# 75%                 8.000000           3.000000        66.0  ...
# max                12.000000          20.000000        66.0  ...
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# count                6.921600e+04       6.944300e+04    70364.000000
# mean                 1.767063e+05       4.397330e+05     2015.998408
# std                  3.955017e+05       8.428115e+05        0.049416
# min                  5.000000e+00       9.000000e+00     2014.000000
# 25%                  7.766700e+04       1.853655e+05     2016.000000
# 50%                  1.262855e+05       3.195910e+05     2016.000000
# 75%                  2.030500e+05       5.126240e+05     2016.000000
# max                  6.640493e+07       1.491392e+08     2016.000000
#
#        landtaxvaluedollarcnt     taxamount  taxdelinquencyyear  \
# count           6.875700e+04  6.992500e+04         1321.000000
# mean            2.662343e+05  5.325672e+03           13.922029
# std             5.409097e+05  1.055420e+04            1.557234
# min             4.000000e+00  2.540000e+00            6.000000
# 25%             7.720100e+04  2.412050e+03           14.000000
# 50%             1.755060e+05  3.953200e+03           14.000000
# 75%             3.270000e+05  6.141260e+03           15.000000
# max             9.401108e+07  1.824155e+06           15.000000
#
#        censustractandblock            id      parcelid      logerror
# count         6.877400e+04  70364.000000  7.036400e+04  70364.000000
# mean          6.049483e+13  38948.813740  1.300694e+07      0.016817
# std           2.110535e+11  22408.699531  3.509369e+06      0.171052
# min           6.037101e+13      1.000000  1.071186e+07     -4.655420
# 25%           6.037312e+13  19396.750000  1.153918e+07     -0.024304
# 50%           6.037575e+13  39117.500000  1.252935e+07      0.006670
# 75%           6.059052e+13  58238.250000  1.420976e+07      0.039233
# max           6.111009e+13  77613.000000  1.676893e+08      5.262999
#
# [8 rows x 58 columns]

# %%
null_counts = df.isnull().sum().sort_values(ascending=False)
null_counts
# Out:
# buildingclasstypeid     70364
# finishedsquarefeet15    70357
# basementsqft            70320
# storytypeid             70320
# yardbuildingsqft26      70299
#                         ...
# roomcnt                     0
# assessmentyear              0
# id                          0
# parcelid                    0
# id                          0
# Length: 63, dtype: int64

# %% [markdown]
# ### Takeaways:
# - Too many nulls in the data
# - Must clean data

# %% [markdown]
# ## 2. Prepare

# %% [markdown]
# #### Missing Values

# %%
# Drop any duplicates in data
df.drop_duplicates(inplace=True)

# %%
# Drop unnecessary columns
cols_to_drop = ['id', 'parcelid','buildingqualitytypeid','calculatedbathnbr','finishedsquarefeet12','fullbathcnt', 'heatingorsystemtypeid','propertycountylandusecode',
'propertylandusetypeid', 'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidzip', 'roomcnt', 'unitcnt', 'censustractandblock']
df = df.drop(columns=cols_to_drop)

# %%
df = prepare.data_prep(
    df,
    cols_to_remove=[],
    prop_required_column=.6,
    prop_required_row=.75)

# %%
df.shape
# Out:
# (63049, 15)

# %%
df.head()
# Out:
#     bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips    latitude  \
# 6           0.0         0.0                        4000.0  6037.0  34733960.0
# 7           2.0         4.0                        3633.0  6037.0  34560018.0
# 9           2.0         2.0                        1090.0  6037.0  33974100.0
# 11          2.0         3.0                        2077.0  6037.0  34012977.0
# 19          0.0         0.0                        1200.0  6037.0  34097714.0
#
#       longitude  lotsizesquarefeet  yearbuilt  structuretaxvaluedollarcnt  \
# 6  -118139298.0            46526.0     1956.0                    176653.0
# 7  -118169806.0             9826.0     2005.0                    222321.0
# 9  -118423000.0            40247.0     2004.0                    232897.0
# 11 -118479243.0             6490.0     1926.0                    210192.0
# 19 -118248712.0             4054.0     1972.0                       595.0
#
#     taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 6            314727.0          2016.0               138074.0    4162.56
# 7            296425.0          2016.0                74104.0    6941.39
# 9            357568.0          2016.0               124671.0    6165.36
# 11           646760.0          2016.0               436568.0    7924.68
# 19             5328.0          2016.0                 4733.0      91.60
#
#     logerror transactiondate
# 6  -0.012041      2017-01-02
# 7   0.042463      2017-01-02
# 9   0.021853      2017-01-02
# 11 -0.040807      2017-01-02
# 19  0.069858      2017-01-02

# %%
# Check for missing values 
df.isnull().sum()
# Out:
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedfinishedsquarefeet    0
# fips                            0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# logerror                        0
# transactiondate                 0
# dtype: int64

# %% [markdown]
# #### Outliers

# %%
df.hist(column='bathroomcnt',figsize=(5, 3))
df.hist(column='bedroomcnt',figsize=(5, 3))
df.hist(column='calculatedfinishedsquarefeet',figsize=(5, 3))
df.hist(column='taxvaluedollarcnt',figsize=(5, 3))
df.hist(column='logerror',figsize=(5, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a255746d0>]],
#       dtype=object)

# %%
# Use IQR to detect and remove outliers

# %%
def get_upper_outliers(s, k):
    q1, q3 = s.quantile([.25, .75])
    iqr = int(q3) - int(q1)
    upper_bound = q3 + k * iqr
    return s.apply(lambda x: max([x - upper_bound, 0]))

def add_upper_outlier_columns(df, k):
    for col in df.select_dtypes('number'):
        df[col + '_outliers'] = get_upper_outliers(df[col], k)
    return df

add_upper_outlier_columns(df, k=1.5)

df.head()
# Out:
#     bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips    latitude  \
# 6           0.0         0.0                        4000.0  6037.0  34733960.0
# 7           2.0         4.0                        3633.0  6037.0  34560018.0
# 9           2.0         2.0                        1090.0  6037.0  33974100.0
# 11          2.0         3.0                        2077.0  6037.0  34012977.0
# 19          0.0         0.0                        1200.0  6037.0  34097714.0
#
#       longitude  lotsizesquarefeet  yearbuilt  structuretaxvaluedollarcnt  \
# 6  -118139298.0            46526.0     1956.0                    176653.0
# 7  -118169806.0             9826.0     2005.0                    222321.0
# 9  -118423000.0            40247.0     2004.0                    232897.0
# 11 -118479243.0             6490.0     1926.0                    210192.0
# 19 -118248712.0             4054.0     1972.0                       595.0
#
#     taxvaluedollarcnt  ...  latitude_outliers  longitude_outliers  \
# 6            314727.0  ...            50723.0                   0
# 7            296425.0  ...                0.0                   0
# 9            357568.0  ...                0.0                   0
# 11           646760.0  ...                0.0                   0
# 19             5328.0  ...                0.0                   0
#
#     lotsizesquarefeet_outliers  yearbuilt_outliers  \
# 6                      29722.0                   0
# 7                          0.0                   0
# 9                      23443.0                   0
# 11                         0.0                   0
# 19                         0.0                   0
#
#    structuretaxvaluedollarcnt_outliers  taxvaluedollarcnt_outliers  \
# 6                                  0.0                         0.0
# 7                                  0.0                         0.0
# 9                                  0.0                         0.0
# 11                                 0.0                         0.0
# 19                                 0.0                         0.0
#
#     assessmentyear_outliers  landtaxvaluedollarcnt_outliers  \
# 6                       0.0                             0.0
# 7                       0.0                             0.0
# 9                       0.0                             0.0
# 11                      0.0                             0.0
# 19                      0.0                             0.0
#
#     taxamount_outliers  logerror_outliers
# 6                  0.0           0.000000
# 7                  0.0           0.002966
# 9                  0.0           0.000000
# 11                 0.0           0.000000
# 19                 0.0           0.030361
#
# [5 rows x 29 columns]

# %%
outlier_cols = [col for col in df if col.endswith('_outliers')]
for col in outlier_cols:
    print('~~~\n' + col)
    data = df[col][df[col] > 0]
    print(data.describe())
# Out:
# ~~~
# bathroomcnt_outliers
# count    1469.000000
# mean        1.194010
# std         1.149934
# min         0.500000
# 25%         0.500000
# 50%         0.500000
# 75%         1.500000
# max        15.500000
# Name: bathroomcnt_outliers, dtype: float64
# ~~~
# bedroomcnt_outliers
# count    801.000000
# mean       0.783396
# std        0.901852
# min        0.500000
# 25%        0.500000
# 50%        0.500000
# 75%        0.500000
# max       19.500000
# Name: bedroomcnt_outliers, dtype: float64
# ~~~
# calculatedfinishedsquarefeet_outliers
# count     2946.000000
# mean      1166.201629
# std       1555.872377
# min          0.500000
# 25%        273.750000
# 50%        666.000000
# 75%       1438.250000
# max      22860.500000
# Name: calculatedfinishedsquarefeet_outliers, dtype: float64
# ~~~
# fips_outliers
# count    5099.0
# mean       19.0
# std         0.0
# min        19.0
# 25%        19.0
# 50%        19.0
# 75%        19.0
# max        19.0
# Name: fips_outliers, dtype: float64
# ~~~
# latitude_outliers
# count       515.000000
# mean      18487.784466
# std       19401.549645
# min           7.000000
# 25%        4996.000000
# 50%       12676.000000
# 75%       25588.500000
# max      123709.000000
# Name: latitude_outliers, dtype: float64
# ~~~
# longitude_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: longitude_outliers, dtype: float64
# ~~~
# lotsizesquarefeet_outliers
# count    9.667000e+03
# mean     1.030180e+05
# std      3.028866e+05
# min      1.000000e+00
# 25%      6.647500e+03
# 50%      2.693900e+04
# 75%      1.018790e+05
# max      6.954206e+06
# Name: lotsizesquarefeet_outliers, dtype: float64
# ~~~
# yearbuilt_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: yearbuilt_outliers, dtype: float64
# ~~~
# structuretaxvaluedollarcnt_outliers
# count    4.383000e+03
# mean     3.146255e+05
# std      5.328410e+05
# min      7.050000e+01
# 25%      5.228150e+04
# 50%      1.515405e+05
# 75%      3.561900e+05
# max      1.001161e+07
# Name: structuretaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# taxvaluedollarcnt_outliers
# count    3.989000e+03
# mean     8.678450e+05
# std      1.434719e+06
# min      7.425000e+02
# 25%      1.641925e+05
# 50%      4.189165e+05
# 75%      9.891745e+05
# max      2.915336e+07
# Name: taxvaluedollarcnt_outliers, dtype: float64
# ~~~
# assessmentyear_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: assessmentyear_outliers, dtype: float64
# ~~~
# landtaxvaluedollarcnt_outliers
# count    3.440000e+03
# mean     6.317606e+05
# std      1.082635e+06
# min      3.850000e+01
# 25%      1.070992e+05
# 50%      2.881135e+05
# 75%      7.014715e+05
# max      1.905058e+07
# Name: landtaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# taxamount_outliers
# count      4214.000000
# mean       9669.423474
# std       16178.283861
# min           1.350000
# 25%        1770.885000
# 50%        4687.855000
# 75%       11076.790000
# max      331181.800000
# Name: taxamount_outliers, dtype: float64
# ~~~
# logerror_outliers
# count    15762.000000
# mean         0.112805
# std          0.245426
# min          0.000008
# 25%          0.014895
# 50%          0.041329
# 75%          0.109163
# max          5.223502
# Name: logerror_outliers, dtype: float64

# %% [markdown]
# #### Train, Validate, Test

# %%
train_validate, test = train_test_split(df, test_size=.30, random_state=123)
train, validate = train_test_split(train_validate, test_size=.20, random_state=123)

print("train observations: ", train.size)
print("validate observations: ", validate.size)
print("test observations: ", test.size)
# Out:
# train observations:  1023903
# validate observations:  255983
# test observations:  548535

# %% [markdown]
# #### Split Data

# %%
# Split into X variables and y target

# X is every column except logerror
X_train = train.drop('logerror',axis=1)
# y is only log error, [[]] to keep as df and not series
y_train = train[['logerror']]

# repeat for validate and test
X_validate = validate.drop('logerror',axis=1)
y_validate = validate[['logerror']]

X_test = test.drop('logerror',axis=1)
y_test = test[['logerror']]

# %% [markdown]
# ### Takeaways:
# - Dropped columns that were not main focus
# - Data is now cleaned and ready for exploration

# %% [markdown]
# ## 3. Explore

# %% [markdown]
# #### Statistical Testing

# %%
# printing stats to determine baseline
print('Log Error Stats\n')
print('average:', train.logerror.mean(),'\n')
print('mode:', train.logerror.mode()[0],'\n')
print('median:', train.logerror.median(),'\n')
# Out:
# Log Error Stats
#
# average: 0.017156111979516345
#
# mode: 0.0026518715020700002
#
# median: 0.00642273011719

# %% [markdown]
# #### Visualizations

# %%
for col in train.columns:
    plt.figure(figsize=(4,2))
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %%
print("Is there a relationship between logerror and taxamount?")
sns.jointplot(y="taxamount", x="logerror", data=train)
plt.show()
# Out:
# Is there a relationship between logerror and taxamount?

# %% [markdown]
# ## 4. Modeling

# %%
X = df[['taxamount', 'logerror']]

# %% [markdown]
# #### Model 1

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
kmeans.predict(X)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
df['cluster'] = kmeans.predict(X)

# %%
kmeans.cluster_centers_
# Out:
# array([[4.64152632e+03, 1.68591353e-02],
#        [3.19735031e+04, 1.65411768e-02]])

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centroids
# Out:
#       taxamount  logerror
# 0   4641.526318  0.016859
# 1  31973.503061  0.016541

# %%
df.groupby('cluster')['taxamount', 'logerror'].mean()
# Out:
#             taxamount  logerror
# cluster
# 0         4641.748982  0.016858
# 1        31981.540670  0.016584

# %%
plt.figure(figsize=(14, 9))

for cluster, subset in df.groupby('cluster'):
    plt.scatter(subset.taxamount, subset.logerror, label='cluster ' + str(cluster), alpha=.6)

centroids.plot.scatter(x='taxamount', y='logerror', c='black', marker='x', s=500, ax=plt.gca(), label='centroid')

plt.legend()
plt.ylabel('Log Error')
plt.xlabel('Tax Amount')
plt.title('Model 1: Visualizing Cluster Centers')
# Out:
# Text(0.5, 1.0, 'Model 1: Visualizing Cluster Centers')

# %% [markdown]
# #### Model 2

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
kmeans.predict(X)

df['cluster'] = kmeans.predict(X)
kmeans.cluster_centers_
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
df.groupby('cluster')['taxamount', 'logerror'].mean()

plt.figure(figsize=(14, 9))

for cluster, subset in df.groupby('cluster'):
    plt.scatter(subset.taxamount, subset.logerror, label='cluster ' + str(cluster), alpha=.6)

centroids.plot.scatter(x='taxamount', y='logerror', c='black', marker='x', s=500, ax=plt.gca(), label='centroid')

plt.legend()
plt.ylabel('Log Error')
plt.xlabel('Tax Amount')
plt.title('Model 2: Visualizing Cluster Centers')
# Out:
# Text(0.5, 1.0, 'Model 2: Visualizing Cluster Centers')

# %% [markdown]
# #### Model 3

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
kmeans.predict(X)

df['cluster'] = kmeans.predict(X)
kmeans.cluster_centers_
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
df.groupby('cluster')['taxamount', 'logerror'].mean()

plt.figure(figsize=(14, 9))

for cluster, subset in df.groupby('cluster'):
    plt.scatter(subset.taxamount, subset.logerror, label='cluster ' + str(cluster), alpha=.6)

centroids.plot.scatter(x='taxamount', y='logerror', c='black', marker='x', s=500, ax=plt.gca(), label='centroid')

plt.legend()
plt.ylabel('Log Error')
plt.xlabel('Tax Amount')
plt.title('Model 3: Visualizing Cluster Centers')
# Out:
# Text(0.5, 1.0, 'Model 3: Visualizing Cluster Centers')

# %% [markdown]
# #### Model 4

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
kmeans.predict(X)

df['cluster'] = kmeans.predict(X)
kmeans.cluster_centers_
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
df.groupby('cluster')['taxamount', 'logerror'].mean()

plt.figure(figsize=(14, 9))

for cluster, subset in df.groupby('cluster'):
    plt.scatter(subset.taxamount, subset.logerror, label='cluster ' + str(cluster), alpha=.6)

centroids.plot.scatter(x='taxamount', y='logerror', c='black', marker='x', s=500, ax=plt.gca(), label='centroid')

plt.legend()
plt.ylabel('Log Error')
plt.xlabel('Tax Amount')
plt.title('Model 4: Visualizing Cluster Centers')
# Out:
# Text(0.5, 1.0, 'Model 4: Visualizing Cluster Centers')

# %% [markdown]
# #### Elbow Method

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X).inertia_ for k in range(2, 12)}).plot(marker='p')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 13), sharex=True, sharey=True)

for ax, k in zip(axs.ravel(), range(2, 6)):
    clusters = KMeans(k).fit(X).predict(X)
    ax.scatter(X.taxamount, X.logerror, c=clusters)
    ax.set(title='k = {}'.format(k), xlabel='Tax Amount', ylabel='Log Error')

# %% [markdown]
# Takeaways:
# - Based on elbow method, should cluster=4

# %% [markdown]
# ## 5. Conclusions

# %% [markdown]
# What are some unanswered questions in my project where more information (additional data sources, deeper understanding, other models or tools) might help improve these results? What are other needs or problems where my model or my approach may be useful?

# %% [markdown]
# Future Investigations
